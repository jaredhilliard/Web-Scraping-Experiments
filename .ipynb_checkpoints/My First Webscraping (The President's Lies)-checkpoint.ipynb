# %%
import requests
r = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html')
#print the first 500 characters of html to see what we're dealing with.
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <!--[if (gt IE 9)|!(IE)]> <!--><html lang="en" class="no-js page-interactive section-opinion page-theme-standard tone-opinion page-interactive-default limit-small layout-xlarge app-interactive" itemid="https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html" itemtype="http://schema.org/NewsArticle" itemscope xmlns:og="http://opengraphprotocol.org/schema/"><!--<![endif]-->
# <!--[if IE 9]> <html lang="en" class="no-js ie9 lt-ie10 page-interactive section-opinion page

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
#cell 1 and 2 are the standard start to every webscraping project.

# %%
results = soup.find_all('span', attrs =  {'class':'short-desc'})
#searches the soup object for all <span> tags in the html code with attribute class = 'short-desc' which is what 
#this article uses to define each particular lie.
len(results)
#note that len(results) here differs from the article, I wonder why?
# Out:
# 180

# %%
#now we can slice the objects like a list to see if what we've done makes sense.
results[0:3]
# Out:
# [<span class="short-desc"><strong>Jan. 21 </strong>“I wasn't a fan of Iraq. I didn't want to go into Iraq.” <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span></span>,
#  <span class="short-desc"><strong>Jan. 21 </strong>“A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.” <span class="short-truth"><a href="http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/" target="_blank">(Trump was on the cover 11 times and Nixon appeared 55 times.)</a></span></span>,
#  <span class="short-desc"><strong>Jan. 23 </strong>“Between 3 million and 5 million illegal votes caused me to lose the popular vote.” <span class="short-truth"><a href="https://www.nytimes.com/2017/01/23/us/politics/donald-trump-congress-democrats.html" target="_blank">(There's no evidence of illegal voting.)</a></span></span>]

# %%
#and once more at the end.
results[177:179]
# Out:
# [<span class="short-desc"><strong>Nov. 1 </strong>“Again, we're the highest-taxed nation, just about, in the world.” <span class="short-truth"><a href="http://www.politifact.com/truth-o-meter/statements/2016/may/08/donald-trump/donald-trump-us-not-highest-taxed-nation-in-world/" target="_blank">(We're not.)</a></span></span>,
#  <span class="short-desc"><strong>Nov. 7 </strong>“When you look at the city with the strongest gun laws in our nation, it's Chicago.” <span class="short-truth"><a href="http://www.politifact.com/truth-o-meter/statements/2017/nov/07/donald-trump/trump-wrongly-repeats-chicago-has-strongest-gun-la/" target="_blank">(Several other cities, including New York and Los Angeles, have stronger gun laws.)</a></span></span>]

# %%
#now we start experimenting with the code to see if we can begin to scrape it correctly.
first_result = results[0]
print(first_result)
# Out:
# <span class="short-desc"><strong>Jan. 21 </strong>“I wasn't a fan of Iraq. I didn't want to go into Iraq.” <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span></span>

# %%
#since we see the date is tagged with the 'strong' tag we'll use the soup .find() method
first_result.find('strong')
# Out:
# <strong>Jan. 21 </strong>

# %%
#this is still a tag object so we need to turn it to actual text.
first_result.find('strong').text
# Out:
# 'Jan. 21\xa0'

# %%
#this \xa0 is an escape character an has length 1, so we'll just slice it off.
first_result.find('strong').text[0:-1]
# Out:
# 'Jan. 21'

# %%
#Now let's add the year.
first_result.find('strong').text[0:-1] + ', 2017'
# Out:
# 'Jan. 21, 2017'

# %%
#Great, now that we've done that, let's see if we can extract the text in the body.  Upon investigating the html we see
#that there aren't any special preceding tags in front of the body, so we can't use the find() method here.
#Instead we will use a method called content which returns the children, the tags and strings nested in a tag.
first_result.contents
# Out:
# [<strong>Jan. 21 </strong>,
#  "“I wasn't a fan of Iraq. I didn't want to go into Iraq.” ",
#  <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span>]

# %%
#Since this is returned as a list object, we can start slicing experimentally
first_result.contents[1]
# Out:
# "“I wasn't a fan of Iraq. I didn't want to go into Iraq.” "

# %%
#We see this gives us the lie we wanted. But we want to clean it up a bit.
first_result.contents[1][1:-2]
# Out:
# "I wasn't a fan of Iraq. I didn't want to go into Iraq."

# %%
#Now for the second piece
first_result.contents[2]
# Out:
# <span class="short-truth"><a href="https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the" target="_blank">(He was for an invasion before he was against it.)</a></span>

# %%
first_result.contents[2].text[1:-1]
# Out:
# 'He was for an invasion before he was against it.'

# %%
#Why does this work?  Well let's look at just the text
first_result.contents[2].text
# Out:
# '(He was for an invasion before he was against it.)'

# %%
#By using the .text method we get rid of the html and can easily scrape the wanted text.
#Then we just had to dispose of the parentheses.

# %%
#Now we finally extract the url.  We'll use the .find() method again since the url is tagged with 'a' and specifically 
#soup treats tag attributes and values like key-value pairs in a dictionary.  Thus we may rip the url as follows:
first_result.find('a')['href']
# Out:
# 'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'

# %% [markdown]
# Alright, we've experimented and figured out how to build the data set.  Now we will merely loop over the beautifulsoup object and build a list.

# %%
records = []
for result in results:
    data = result.find('strong').text[0:-1] + ', 2017'
    lie = result.contents[1][1:-2]
    explanation = result.contents[2].text[1:-1]
    url = result.find('a')['href']
    records.append((data, lie, explanation, url))
    
len(records)
# Out:
# 180

# %%
records[0:5]
# Out:
# [('Jan. 21, 2017',
#   "I wasn't a fan of Iraq. I didn't want to go into Iraq.",
#   'He was for an invasion before he was against it.',
#   'https://www.buzzfeed.com/andrewkaczynski/in-2002-donald-trump-said-he-supported-invading-iraq-on-the'),
#  ('Jan. 21, 2017',
#   'A reporter for Time magazine — and I have been on their cover 14 or 15 times. I think we have the all-time record in the history of Time magazine.',
#   'Trump was on the cover 11 times and Nixon appeared 55 times.',
#   'http://nation.time.com/2013/11/06/10-things-you-didnt-know-about-time/'),
#  ('Jan. 23, 2017',
#   'Between 3 million and 5 million illegal votes caused me to lose the popular vote.',
#   "There's no evidence of illegal voting.",
#   'https://www.nytimes.com/2017/01/23/us/politics/donald-trump-congress-democrats.html'),
#  ('Jan. 25, 2017',
#   'Now, the audience was the biggest ever. But this crowd was massive. Look how far back it goes. This crowd was massive.',
#   "Official aerial photos show Obama's 2009 inauguration was much more heavily attended.",
#   'https://www.nytimes.com/2017/01/21/us/politics/trump-white-house-briefing-inauguration-crowd-size.html'),
#  ('Jan. 25, 2017',
#   'Take a look at the Pew reports (which show voter fraud.)',
#   'The report never mentioned voter fraud.',
#   'https://www.nytimes.com/2017/01/24/us/politics/unauthorized-immigrant-voting-trump-lie.html')]

# %%
#Finally then, we want to make this into a pandas dataframe.
import pandas as pd
df = pd.DataFrame(records, columns = ['date','lie','explanation', 'url'])
df.head()
#Why am I not getting output?
# Out:
#             date                                                lie  \
# 0  Jan. 21, 2017  I wasn't a fan of Iraq. I didn't want to go in...
# 1  Jan. 21, 2017  A reporter for Time magazine — and I have been...
# 2  Jan. 23, 2017  Between 3 million and 5 million illegal votes ...
# 3  Jan. 25, 2017  Now, the audience was the biggest ever. But th...
# 4  Jan. 25, 2017  Take a look at the Pew reports (which show vot...
#
#                                          explanation  \
# 0   He was for an invasion before he was against it.
# 1  Trump was on the cover 11 times and Nixon appe...
# 2             There's no evidence of illegal voting.
# 3  Official aerial photos show Obama's 2009 inaug...
# 4            The report never mentioned voter fraud.
#
#                                                  url
# 0  https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1  http://nation.time.com/2013/11/06/10-things-yo...
# 2  https://www.nytimes.com/2017/01/23/us/politics...
# 3  https://www.nytimes.com/2017/01/21/us/politics...
# 4  https://www.nytimes.com/2017/01/24/us/politics...

# %%
df.tail()
# Out:
#               data                                                lie  \
# 175  Oct. 25, 2017      We have trade deficits with almost everybody.
# 176  Oct. 27, 2017  Wacky & totally unhinged Tom Steyer, who has b...
# 177   Nov. 1, 2017  Again, we're the highest-taxed nation, just ab...
# 178   Nov. 7, 2017  When you look at the city with the strongest g...
# 179  Nov. 11, 2017  I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                         We're not.
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                    url
# 175  https://www.bea.gov/newsreleases/international...
# 176  https://www.opensecrets.org/donor-lookup/resul...
# 177  http://www.politifact.com/truth-o-meter/statem...
# 178  http://www.politifact.com/truth-o-meter/statem...
# 179  https://www.nytimes.com/interactive/2017/12/10...

# %%
df
# Out:
#               data                                                lie  \
# 0    Jan. 21, 2017  I wasn't a fan of Iraq. I didn't want to go in...
# 1    Jan. 21, 2017  A reporter for Time magazine — and I have been...
# 2    Jan. 23, 2017  Between 3 million and 5 million illegal votes ...
# 3    Jan. 25, 2017  Now, the audience was the biggest ever. But th...
# 4    Jan. 25, 2017  Take a look at the Pew reports (which show vot...
# 5    Jan. 25, 2017  You had millions of people that now aren't ins...
# 6    Jan. 25, 2017  So, look, when President Obama was there two w...
I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 0     He was for an invasion before he was against it.
# 1    Trump was on the cover 11 times and Nixon appe...
# 2               There's no evidence of illegal voting.
# 3    Official aerial photos show Obama's 2009 inaug...
# 4              The report never mentioned voter fraud.
# 5    The real number is less than 1 million, accord...
# 6    There were no gun homicide victims in Chicago ...
# 7                       Vetting lasts up to two years.
# 8               Most of the cuts were already planned.
# 9                                 It never apologized.
# 10                       There is no support for this.
# 11   At least 746 people were detained and processe...
# 12            There is no evidence of paid protesters.
# 13                                It never apologized.
# 14                  About 60,000 people were affected.
# 15   Much of the price drop was projected before Tr...
# 16    Terrorism has been reported on, often in detail.
# 17                                It didn't apologize.
# 18                   The group’s origins date to 2004.
# 19                It was higher in the 1980s and '90s.
# 20   The Defense Department projected this price dr...
# 21              It was part of Cuomo's first question.
# 22       The Gorsuch comments were later corroborated.
# 23         Trump knew about Flynn's actions for weeks.
# 24                             The media did cover it.
# 25   George H.W. Bush, Bill Clinton and Barack Obam...
# 26           Delta's problems happened two days later.
# 27   The jobs are a result of its investment plans ...
# 28   Not always. They have released classified info...
# 29                            The rollout was chaotic.
# ..                                                 ...
# 150  The cost cuts were planned before he became pr...
# 151  The cost cuts were planned before he became pr...
# 152                                         We're not.
# 153                        The Senate didn't say that.
# 154                                         We're not.
# 155                                         We're not.
# 156                        The real number is smaller.
# 157                  The group’s origins date to 2004.
# 158  Corker asked the Times reporter to record the ...
# 159                                         We're not.
# 160        The effectiveness rate is about 60 percent.
# 161                                         We're not.
# 162          Ireland has no plans to cut its tax rate.
# 163  They did call families of soldiers killed in a...
# 164     Trump himself has bragged about groping women.
# 165                                         We're not.
# 166                                         We're not.
# 167  Taxes in the U.S. are lower than in most devel...
# 168                                         We're not.
# 169                                         We're not.
# 170                  The group’s origins date to 2004.
# 171  The wife confirmed Representative Frederica Wi...
# 172                       The real number was smaller.
# 173            Category 5 storms have hit land before.
# 174  The real number is estimated to be less than 1...
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                         We're not.
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                    url
# 0    https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1    http://nation.time.com/2013/11/06/10-things-yo...
# 2    https://www.nytimes.com/2017/01/23/us/politics...
# 3    https://www.nytimes.com/2017/01/21/us/politics...
# 4    https://www.nytimes.com/2017/01/24/us/politics...
# 5    https://www.nytimes.com/2017/03/13/us/politics...
# 6    https://www.dnainfo.com/chicago/2017-chicago-m...
# 7    https://www.nytimes.com/interactive/2017/01/29...
# 8    https://www.washingtonpost.com/news/fact-check...
# 9    https://www.nytimes.com/2016/11/13/us/election...
# 10   http://www.pewresearch.org/fact-tank/2016/11/1...
# 11   http://markets.on.nytimes.com/research/stocks/...
# 12   https://www.nytimes.com/2017/01/28/nyregion/jf...
# 13   https://www.nytimes.com/2016/11/13/us/election...
# 14   http://www.politifact.com/truth-o-meter/statem...
# 15   https://www.washingtonpost.com/news/fact-check...
# 16   https://www.nytimes.com/2017/02/07/us/politics...
# 78  April 29, 2017  I think our side's been proven very strongly. ...
# 79     May 1, 2017  Well, we are protecting pre-existing condition...
#
#                                           explanation  \
# 60                   He knew Steve Bannon since 2011.
# 61  At this point, he had not nominated anyone for...
# 62  There were separate headlines for print and we...
# 63  NATO has been engaged in counterterrorism effo...
# 64          The campaign was expected to take months.
# 65            There's no evidence of paid protesters.
# 66                                            He did.
# 67     Much of the price cuts were already projected.
# 68                 He criticized it as early as 2010.
# 69  The bill to extend health benefits for certain...
# 70  The U.S. had an $8.1 billion trade surplus, no...
# 71              Those are not Jon Ossoff's positions.
# 72  Much of the price cuts were planned before Trump.
# 73                           China stopped years ago.
# 74  Much of the price cuts were planned before Trump.
# 75                       The deal was struck in 2014.
# 76                             China stopped in 2014.
# 77        Most of the cuts were planned before Trump.
# 78  There's still no evidence Trump's phones were ...
# 79  The bill weakens protections for people with p...
#
#                                                   url
# 60  https://www.nytimes.com/2017/04/12/us/politics...
# 61  https://www.nytimes.com/2017/04/12/us/politics...
# 62  https://www.nytimes.com/2017/03/23/us/politics...
# 63  https://www.nytimes.com/2017/04/12/us/politics...
# 64  https://www.washingtonpost.com/news/the-fix/wp...
# 65  https://www.nytimes.com/2017/04/15/us/politics...
# 66  https://www.nytimes.com/2017/04/14/business/ch...
# 67  https://www.washingtonpost.com/news/fact-check...
# 68  https://www.washingtonpost.com/news/fact-check...
# 69  http://www.pbs.org/newshour/rundown/retired-co...
# 70  http://www.factcheck.org/2017/05/trumps-100-da...
# 71  http://www.mdjonline.com/opinion/jon-ossoff-vo...
# 72  https://www.washingtonpost.com/news/fact-check...
# 73  https://www.nytimes.com/2017/04/07/world/asia/...
# 74  https://www.washingtonpost.com/news/fact-check...
# 75  https://www.nytimes.com/2017/03/01/us/politics...
# 76  https://www.nytimes.com/2017/04/07/world/asia/...
# 77  https://www.washingtonpost.com/news/fact-check...
# 78  https://www.nytimes.com/2017/03/20/us/politics...
# 79  https://www.nytimes.com/2017/04/26/upshot/what...

# %%
#When investigating the entire dataset we can see some dates aren't abbreviated.  
#I'm not sure how we would know this without looking at the entire thing.  Still, let's fix that.
df['date'] = pd.to_datetime(df['date'])
df[60:80]
# Out:
#          date                                                lie  \
# 60 2017-04-11  I like Steve, but you have to remember he was ...
# 61 2017-04-12  You can't do it faster, because they're obstru...
# 62 2017-04-12  The New York Times said the word wiretapped in...
# 63 2017-04-12  The secretary general and I had a productive d...
# 64 2017-04-12  Mosul was supposed to last for a week and now ...
# 65 2017-04-16  Someone should look into who paid for the smal...
# 66 2017-04-18  The fake media goes, ‘Donald Trump changed his...
# 67 2017-04-21  On 90 planes I saved $725 million. It's actual...
# 68 2017-04-21  When WikiLeaks came out ... never heard of Wik...
# 69 2017-04-27  I want to help our miners while the Democrats ...
# 70 2017-04-28  The trade deficit with Mexico is close to $70 ...
# 71 2017-04-28  She's running against someone who's going to r...
# 72 2017-04-28  The F-35 fighter jet program — it was way over...
# 73 2017-04-29  As you know, I've been a big critic of China, ...
# 74 2017-04-29  I've already saved more than $725 million on a...
# 75 2017-04-29  We're also getting NATO countries to finally s...
# 76 2017-04-29  When they talk about currency manipulation, an...
# 77 2017-04-29  I was negotiating to reduce the price of the b...
# 78 2017-04-29  I think our side's been proven very strongly. ...
# 79 2017-05-01  Well, we are protecting pre-existing condition...
#
#                                           explanation  \
# 60                   He knew Steve Bannon since 2011.
# 61  At this point, he had not nominated anyone for...
# 62  There were separate headlines for print and we...
# 63  NATO has been engaged in counterterrorism effo...
# 64          The campaign was expected to take months.
# 65            There's no evidence of paid protesters.
# 66                                            He did.
# 67     Much of the price cuts were already projected.
# 68                 He criticized it as early as 2010.
# 69  The bill to extend health benefits for certain...
# 70  The U.S. had an $8.1 billion trade surplus, no...
# 71              Those are not Jon Ossoff's positions.
# 72  Much of the price cuts were planned before Trump.
# 73                           China stopped years ago.
# 74  Much of the price cuts were planned before Trump.
# 75                       The deal was struck in 2014.
# 76                             China stopped in 2014.
# 77        Most of the cuts were planned before Trump.
# 78  There's still no evidence Trump's phones were ...
# 79  The bill weakens protections for people with p...
#
#                                                   url
# 60  https://www.nytimes.com/2017/04/12/us/politics...
# 61  https://www.nytimes.com/2017/04/12/us/politics...
# 62  https://www.nytimes.com/2017/03/23/us/politics...
# 63  https://www.nytimes.com/2017/04/12/us/politics...
# 64  https://www.washingtonpost.com/news/the-fix/wp...
# 65  https://www.nytimes.com/2017/04/15/us/politics...
# 66  https://www.nytimes.com/2017/04/14/business/ch...
# 67  https://www.washingtonpost.com/news/fact-check...
# 68  https://www.washingtonpost.com/news/fact-check...
# 69  http://www.pbs.org/newshour/rundown/retired-co...
# 70  http://www.factcheck.org/2017/05/trumps-100-da...
# 71  http://www.mdjonline.com/opinion/jon-ossoff-vo...
# 72  https://www.washingtonpost.com/news/fact-check...
# 73  https://www.nytimes.com/2017/04/07/world/asia/...
# 74  https://www.washingtonpost.com/news/fact-check...
# 75  https://www.nytimes.com/2017/03/01/us/politics...
# 76  https://www.nytimes.com/2017/04/07/world/asia/...
# 77  https://www.washingtonpost.com/news/fact-check...
# 78  https://www.nytimes.com/2017/03/20/us/politics...
# 79  https://www.nytimes.com/2017/04/26/upshot/what...

# %%
df.tail()
# Out:
#           date                                                lie  \
# 175 2017-10-25      We have trade deficits with almost everybody.
# 176 2017-10-27  Wacky & totally unhinged Tom Steyer, who has b...
# 177 2017-11-01  Again, we're the highest-taxed nation, just ab...
# 178 2017-11-07  When you look at the city with the strongest g...
# 179 2017-11-11  I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                         We're not.
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                    url
# 175  https://www.bea.gov/newsreleases/international...
# 176  https://www.opensecrets.org/donor-lookup/resul...
# 177  http://www.politifact.com/truth-o-meter/statem...
# 178  http://www.politifact.com/truth-o-meter/statem...
# 179  https://www.nytimes.com/interactive/2017/12/10...

# %%
#index = false means don't include the index on the left.
df.to_csv('trump_lies.csv', index = False, encoding = 'utf-8')

# %% [markdown]
# And that's it!  The final code is below to quickly see what to follow when attempting other webscraping projects.

# %%
import requests  
r = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html')

from bs4 import BeautifulSoup  
soup = BeautifulSoup(r.text, 'html.parser')  
results = soup.find_all('span', attrs={'class':'short-desc'})

records = []  
for result in results:  
    date = result.find('strong').text[0:-1] + ', 2017'
    lie = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((date, lie, explanation, url))

import pandas as pd  
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])  
df['date'] = pd.to_datetime(df['date'])  
df.to_csv('trump_lies.csv', index=False, encoding='utf-8')

# %%
df.tail()
